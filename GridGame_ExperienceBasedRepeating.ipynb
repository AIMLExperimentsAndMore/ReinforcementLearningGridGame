# %%
from matplotlib import pylab as plt
from Gridworld import Gridworld
import tensorflow as tf
import random
import numpy as np
import keras
from collections import deque
from tensorflow.keras import(
    layers,
    models,
    metrics,
    losses,
    optimizers,
)

# %%
# Custom neural network layer designed for a grid game agent.
# Inherits from Keras' Layer class, allowing integration within the Keras framework.
class model(keras.Model):
    def __init__(self):
        # Initialize the parent Layer to ensure proper setup of the underlying mechanisms.
        super().__init__()

        # Define the first dense layer with 150 units.
        self.layer1 = keras.layers.Dense(150, use_bias=False, name='layer1')
        # Define the second dense layer with 100 units.
        self.layer2 = keras.layers.Dense(100, use_bias=True, name='layer2')
        # Define the third dense (output) layer with 4 units (4 because there are 4 possible actions in the game)
        self.layer3 = keras.layers.Dense(4, use_bias=True, name='layer3')

    def call(self, inputs):
        # Forward propagation through the network begins with the first dense layer.
        x = self.layer1(inputs)
        # Apply the ReLU activation function to introduce non-linearity.
        x = tf.nn.relu(x)
        # Pass the output through the second dense layer.
        x = self.layer2(x)
        # Again, apply the ReLU activation function to capture non-linear relationships.
        x = tf.nn.relu(x)

        # Process the data through the final dense layer to produce the network output.
        # Note: No activation function is applied after this layer. This is often
        # intentional in reinforcement learning setups, where raw scores (logits)
        # may be used directly or processed with a softmax/cross-entropy loss externally.
        x = self.layer3(x)
        
        # Return the final computed output.
        return x

# Note:
# The input dimensions for this model are inferred at runtime when the model is first called.
# This dynamic input size handling is a feature of Keras that promotes flexibility in designing models.

# %%
action_set = {
    0: 'u',
    1: 'd',
    2: 'l',
    3: 'r',
}

# %%
# create an instance of the model while additionally defining loss and optimizer
optimizer = keras.optimizers.SGD(learning_rate=1e-3)
loss_fn = keras.losses.MeanSquaredError()
agent = model()

# %% [markdown]
# ###Training Loop

# %%
# Initialize a counter to track the number of training iterations (loops/epochs)
mem_size = 1000
batch_size = 200
replay = deque(maxlen=mem_size)
max_moves = 50
epochs = 15000
#TensorArray being expandable while runtime
loss_list = tf.TensorArray(tf.float32, size=0, dynamic_size=True, clear_after_read=False)
move_list = tf.TensorArray(tf.float32, size=0, dynamic_size=True, clear_after_read=False)
win_list = tf.TensorArray(tf.float32, size=0, dynamic_size=True, clear_after_read=False)
loop_cnt = 0

gamma = 0.9
epsilon = 0.3

# Loop over the specified number of epochs
for i in range(epochs):  # B: Iterate through each training epoch
    print('epoch= ', i)
    loop_cnt += 1  # Increment the loop counter for each epoch

    # Initialize a new Gridworld game with a 4x4 grid and a static configuration
    game = Gridworld(size=4, mode='random')  # C

    # Render the game board as a NumPy array, reshape it to a 1x64 vector,
    # and add a small amount of random noise to slightly perturb the state.
    state_ = game.board.render_np().reshape(1, 64) + np.random.rand(1, 64) / 10.0  # D

    # Convert the NumPy state representation to a TensorFlow tensor for model input
    state1 = tf.convert_to_tensor(state_)
    
    # Set a status flag to indicate that the game is ongoing
    status = 1  # F

    # Initialize counters for moves within the current game and to accumulate loss
    mov = 0
    loss_tmp = 0

    # Continue playing until the game signals termination (status != 1)
    while status == 1:  # G
        mov += 1  # Increment the move counter
        #print(f"move: {mov}")

        # Obtain Q-values by forwarding the current state through the agent's network
        qval = agent(state1)  # H

        # Convert the Q-values tensor to a NumPy array (note: this conversion might reduce performance)
        qval_ = qval.numpy()

        # Epsilon-greedy action selection: with probability epsilon, choose a random action for exploration,
        # otherwise choose the action with the highest Q-value
        if random.random() < epsilon:  # I
            action_ = np.random.randint(0, 4)
        else:
            action_ = np.argmax(qval_)

        # Map the selected action index to the corresponding action in the predefined action set
        action = action_set[action_]  # J

        # Apply the selected action to the game environment
        game.makeMove(action)  # K

        # Render the updated game state, reshape, and add noise as before
        state2_ = game.board.render_np().reshape(1, 64) + np.random.rand(1, 64) / 10.0
        state2 = tf.convert_to_tensor(state2_)

        # Obtain the reward from the environment after the action
        reward_ = game.reward()

        # Convert the reward to a TensorFlow tensor and cast it to float
        reward = tf.convert_to_tensor(reward_)
        reward = tf.cast(reward, float)

        # Determine if the episode is complete. Here, a positive reward signifies the end of an episode.
        done = True if reward_ > 0 else False

        # Package the experience tuple (current state, action taken, reward, next state, done flag)
        exp = (state1, action_, reward, state2, done)  # G

        # Append the experience tuple to the replay memory for future training
        replay.append(exp)  # H

        # Update the current state to the new state
        state1 = state2

        # Once enough experiences are collected, sample a minibatch for training
        if len(replay) > batch_size:  # I
            #print('optimize')
            # Randomly sample a minibatch from the replay memory
            minibatch = random.sample(replay, batch_size)  # J

            # Extract batches of states, actions, rewards, next states, and done flags from the minibatch
            state1_batch = tf.convert_to_tensor([s1 for (s1, a, r, s2, d) in minibatch])  # K
            action_batch = tf.convert_to_tensor([a for (s1, a, r, s2, d) in minibatch])
            reward_batch = tf.convert_to_tensor([r for (s1, a, r, s2, d) in minibatch])
            state2_batch = tf.convert_to_tensor([s2 for (s1, a, r, s2, d) in minibatch])
            # The done flag is kept as a list for further arithmetic operations
            done_batch = [d for (s1, a, r, s2, d) in minibatch]

            #print('batchsize: ', batch_size)

            # Begin recording gradients for backpropagation
            # together tape.gradient later, only within this section backpropagation is carried out
            with tf.GradientTape() as tape:
                # Compute Q-values for the batch of current states
                Q1 = agent(state1_batch)    # Expected shape: [batch_size, 1, 4]
                Q1 = tf.squeeze(Q1)         # Reshape to: [batch_size, 4]

                # For each predicted q vector, select the q value for the stored action
                X = [row[index] for row, index in zip(Q1, action_batch)]
                X = tf.convert_to_tensor(X)

                #print('X size= ', tf.size(X))
                #print('X size= ', X)

                # Compute target Q-values without tracking gradients for the stored second steps
                with tape.stop_recording():
                    # Forward pass for the batch of next states
                    Q2 = agent(state2_batch)
                    Q2 = tf.squeeze(Q2)
                    I = tf.ones((1, batch_size))
                    # Compute the target Q-value using the Bellman equation:
                    # in the second step no action is stored. The maximum Q value is chosen
                    Y = reward_batch + gamma * ((I - done_batch) * tf.reduce_max(Q2, axis=1))

                # Calculate the loss between predicted Q-values and target Q-values
                loss = loss_fn([X], [Y])  # P
                #print('loss= ', loss)
                loss_tmp = loss_tmp + loss.numpy()

                # Compute gradients of the loss with respect to the agent's trainable weights
                grads = tape.gradient(loss, agent.trainable_weights)
                # Apply the computed gradients to update the agent's weights (currently commented out)
                optimizer.apply_gradients(zip(grads, agent.trainable_weights))

    # After exiting the inner loop, check termination conditions:
    # If a terminal reward is received (reward != -1) or the move count exceeds max_moves, end the game.
    
        if reward != -1 or mov > max_moves:  # O
            print(f"mov: {mov}")
            status = 0
            if reward == 10:
                win_list = win_list.write(loop_cnt,1)
            else:
                win_list = win_list.write(loop_cnt,0)

    # Record the cumulative loss for this epoch into loss_list
    loss_list = loss_list.write(loop_cnt, loss_tmp)
    move_list = move_list.write(loop_cnt,mov)
# Out:
# epoch=  0
# mov: 51
# epoch=  1
# mov: 6
# epoch=  2
# mov: 51
# epoch=  3
# mov: 2
# epoch=  4
# mov: 51
# epoch=  5
# mov: 42
# epoch=  6
# mov: 16
# epoch=  7
# mov: 3
# epoch=  8
# mov: 51
# epoch=  9
# mov: 51
# epoch=  10
# mov: 2
# epoch=  11
# mov: 51
# epoch=  12
# mov: 51
# epoch=  13
# mov: 7
# epoch=  14
# mov: 2
# epoch=  15
# mov: 1
# epoch=  16
# mov: 7
# epoch=  17
# mov: 51
# epoch=  18
# mov: 2
# epoch=  19
# mov: 51
# epoch=  20
# mov: 49
# epoch=  21
# mov: 51
# epoch=  22
# mov: 51
# epoch=  23
# mov: 51
# epoch=  24
# mov: 1
# epoch=  25
# mov: 5
# epoch=  26
# mov: 51
# epoch=  27
# mov: 1
# epoch=  28
# mov: 2
# epoch=  29
# mov: 39
# epoch=  30
# mov: 2
# epoch=  31
# mov: 8
# epoch=  32
# mov: 3
# epoch=  33
# mov: 2
# epoch=  34
# mov: 51
# epoch=  35
# mov: 49
# epoch=  36
# mov: 1
# epoch=  37
# mov: 49
# epoch=  38
# mov: 1
# epoch=  39
# mov: 51
# epoch=  40
# mov: 5
# epoch=  41
# mov: 24
# epoch=  42
# mov: 51
# epoch=  43
# mov: 1
# epoch=  44
# mov: 46
# epoch=  45
# mov: 51
# epoch=  46
# mov: 51
# epoch=  47
# mov: 1
# epoch=  48
# mov: 15
# epoch=  49
# mov: 3
# epoch=  50
# mov: 51
# epoch=  51
# mov: 5
# epoch=  52
# mov: 51
# epoch=  53
# mov: 51
# epoch=  54
# mov: 51
# epoch=  55
# mov: 51
# epoch=  56
# mov: 3
# epoch=  57
# mov: 27
# epoch=  58
# mov: 4
# epoch=  59
# mov: 50
# epoch=  60
# mov: 30
# epoch=  61
# mov: 51
# epoch=  62
# mov: 4
# epoch=  63
# mov: 20
# epoch=  64
# mov: 2
# epoch=  65
# mov: 1
# epoch=  66
# mov: 36
# epoch=  67
# mov: 4
# epoch=  68
# mov: 51
# epoch=  69
# mov: 3
# epoch=  70
# mov: 42
# epoch=  71
# mov: 9
# epoch=  72
# mov: 10
# epoch=  73
# mov: 51
# epoch=  74
# mov: 10
# epoch=  75
# mov: 10
# epoch=  76
# mov: 42
# epoch=  77
# mov: 4
# epoch=  78
# mov: 51
# epoch=  79
# mov: 18
# epoch=  80
# mov: 26
# epoch=  81
# mov: 5
# epoch=  82
# mov: 51
# epoch=  83
# mov: 11
# epoch=  84
# mov: 51
# epoch=  85
# mov: 9
# epoch=  86
# mov: 31
# epoch=  87
# mov: 3
# epoch=  88
# mov: 34
# epoch=  89
# mov: 1
# epoch=  90
# mov: 51
# epoch=  91
# mov: 51
# epoch=  92
# mov: 51
# epoch=  93
# mov: 1
# epoch=  94
# mov: 6
# epoch=  95
# mov: 51
# epoch=  96
# mov: 12
# epoch=  97
# mov: 43
# epoch=  98
# mov: 20
# epoch=  99
# mov: 51
# epoch=  100
# mov: 2
# epoch=  101
# mov: 51
# epoch=  102
# mov: 6
# epoch=  103
# mov: 7
# epoch=  104
# mov: 1
# epoch=  105
# mov: 34
# epoch=  106
# mov: 4
# epoch=  107
# mov: 51
# epoch=  108
# mov: 21
# epoch=  109
# mov: 51
# epoch=  110
# mov: 51
# epoch=  111
# mov: 51
# epoch=  112
# mov: 51
# epoch=  113
# mov: 4
# epoch=  114
# mov: 3
# epoch=  115
# mov: 10
# epoch=  116
# mov: 1
# epoch=  117
# mov: 51
# epoch=  118
# mov: 3
# epoch=  119
# mov: 2
# epoch=  120
# mov: 3
# epoch=  121
# mov: 51
# epoch=  122
# mov: 51
# epoch=  123
# mov: 36
# epoch=  124
# mov: 21
# epoch=  125
# mov: 7
# epoch=  126
# mov: 49
# epoch=  127
# mov: 51
# epoch=  128
# mov: 13
# epoch=  129
# mov: 51
# epoch=  130
# mov: 15
# epoch=  131
# mov: 3
# epoch=  132
# mov: 36
# epoch=  133
# mov: 51
# epoch=  134
# mov: 30
# epoch=  135
# mov: 8
# epoch=  136
# mov: 51
# epoch=  137
# mov: 2
# epoch=  138
# mov: 6
# epoch=  139
# mov: 51
# epoch=  140
# mov: 25
# epoch=  141
# mov: 4
# epoch=  142
# mov: 1
# epoch=  143
# mov: 51
# epoch=  144
# mov: 51
# epoch=  145
# mov: 23
# epoch=  146
# mov: 40
# epoch=  147
# mov: 51
# epoch=  148
# mov: 51
# epoch=  149
# mov: 5
# epoch=  150
# mov: 51
# epoch=  151
# mov: 51
# epoch=  152
# mov: 3
# epoch=  153
# mov: 51
# epoch=  154
# mov: 51
# epoch=  155
# mov: 7
# epoch=  156
# mov: 2
# epoch=  157
# mov: 51
# epoch=  158
# mov: 51
# epoch=  159
# mov: 2
# epoch=  160
# mov: 51
# epoch=  161
# mov: 10
# epoch=  162
# mov: 13
# epoch=  163
# mov: 3
# epoch=  164
# mov: 4
# epoch=  165
# mov: 2
# epoch=  166
# mov: 7
# epoch=  167
# mov: 2
# epoch=  168
# mov: 2
# epoch=  169
# mov: 8
# epoch=  170
# mov: 1
# epoch=  171
# mov: 51
# epoch=  172
# mov: 15
# epoch=  173
# mov: 42
# epoch=  174
# mov: 1
# epoch=  175
# mov: 23
# epoch=  176
# mov: 7
# epoch=  177
# mov: 1
# epoch=  178
# mov: 12
# epoch=  179
# mov: 51
# epoch=  180
# mov: 37
# epoch=  181
# mov: 46
# epoch=  182
# mov: 51
# epoch=  183
# mov: 2
# epoch=  184
# mov: 51
# epoch=  185
# mov: 5
# epoch=  186
# mov: 10
# epoch=  187
# mov: 49
# epoch=  188
# mov: 27
# epoch=  189
# mov: 22
# epoch=  190
# mov: 34
# epoch=  191
# mov: 51
# epoch=  192
# mov: 1
# epoch=  193
# mov: 51
# epoch=  194
# mov: 2
# epoch=  195
# mov: 12
# epoch=  196
# mov: 51
# epoch=  197
# mov: 1
# epoch=  198
# mov: 51
# epoch=  199
# mov: 1
# epoch=  200
# mov: 39
# epoch=  201
# mov: 6
# epoch=  202
# mov: 4
# epoch=  203
# mov: 3
# epoch=  204
# mov: 2
# epoch=  205
# mov: 3
# epoch=  206
# mov: 51
# epoch=  207
# mov: 29
# epoch=  208
# mov: 51
# epoch=  209
# mov: 8
# epoch=  210
# mov: 51
# epoch=  211
# mov: 2
# epoch=  212
# mov: 43
# epoch=  213
# mov: 3
# epoch=  214
# mov: 51
# epoch=  215
# mov: 51
# epoch=  216
# mov: 6
# epoch=  217
# mov: 4
# epoch=  218
# mov: 51
# epoch=  219
# mov: 51
# epoch=  220
# mov: 32
# epoch=  221
# mov: 51
# epoch=  222
# mov: 14
# epoch=  223
# mov: 51
# epoch=  224
# mov: 8
# epoch=  225
# mov: 51
# epoch=  226
# mov: 51
# epoch=  227
# mov: 1
# epoch=  228
# mov: 10
# epoch=  229
# mov: 51
# epoch=  230
# mov: 2
# epoch=  231
# mov: 12
# epoch=  232
# mov: 51
# epoch=  233
# mov: 3
# epoch=  234
# mov: 51
# epoch=  235
# mov: 8
# epoch=  236
# mov: 8
# epoch=  237
# mov: 29
# epoch=  238
# mov: 51
# epoch=  239
# mov: 51
# epoch=  240
# mov: 1
# epoch=  241
# mov: 2
# epoch=  242
# mov: 51
# epoch=  243
# mov: 7
# epoch=  244
# mov: 2
# epoch=  245
# mov: 22
# epoch=  246
# mov: 8
# epoch=  247
# mov: 3
# epoch=  248
# mov: 1
# epoch=  249
# mov: 1
# epoch=  250
# mov: 40
# epoch=  251
# mov: 51
# epoch=  252
# mov: 4
# epoch=  253
# mov: 24
# epoch=  254
# mov: 4
# epoch=  255
# mov: 8
# epoch=  256
# mov: 17
# epoch=  257
# mov: 32
# epoch=  258
# mov: 3
# epoch=  259
# mov: 10
# epoch=  260
# mov: 51
# epoch=  261
# mov: 51
# epoch=  262
# mov: 1
# epoch=  263
# mov: 6
# epoch=  264
# mov: 16
# epoch=  265
# mov: 46
# epoch=  266
# mov: 51
# epoch=  267
# mov: 1
# epoch=  268
# mov: 51
# epoch=  269
# mov: 6
# epoch=  270
# mov: 5
# epoch=  271
# mov: 15
# epoch=  272
# mov: 16
# epoch=  273
# mov: 1
# epoch=  274
# mov: 3
# epoch=  275
# mov: 4
# epoch=  276
# mov: 1
# epoch=  277
# mov: 4
# epoch=  278
# mov: 9
# epoch=  279
# mov: 2
# epoch=  280
# mov: 51
# epoch=  281
# mov: 3
# epoch=  282
# mov: 44
# epoch=  283
# mov: 51
# epoch=  284
# mov: 51
# epoch=  285
# mov: 14
# epoch=  286
# mov: 39
# epoch=  287
# mov: 22
# epoch=  288
# mov: 9
# epoch=  289
# mov: 3
# epoch=  290
# mov: 30
# epoch=  291
# mov: 31
# epoch=  292
# mov: 51
# epoch=  293
# mov: 51
# epoch=  294
# mov: 11
# epoch=  295
# mov: 1
# epoch=  296
# mov: 13
# epoch=  297
# mov: 24
# epoch=  298
# mov: 14
# epoch=  299
# mov: 3
# epoch=  300
# mov: 7
# epoch=  301
# mov: 7
# epoch=  302
# mov: 51
# epoch=  303
# mov: 8
# epoch=  304
# mov: 1
# epoch=  305
# mov: 51
# epoch=  306
# mov: 23
# epoch=  307
# mov: 22
# epoch=  308
# mov: 5
# epoch=  309
# mov: 3
# epoch=  310
# mov: 51
# epoch=  311
# mov: 4
# epoch=  312
# mov: 51
# epoch=  313
# mov: 5
# epoch=  314
# mov: 51
# epoch=  315
# mov: 51
# epoch=  316
# mov: 3
# epoch=  317
# mov: 2
# epoch=  318
# mov: 51
# epoch=  319
# mov: 7
# epoch=  320
# mov: 51
# epoch=  321
# mov: 21
# epoch=  322
# mov: 1
# epoch=  323
# mov: 6
# epoch=  324
# mov: 51
# epoch=  325
# mov: 3
# epoch=  326
# mov: 51
# epoch=  327
# mov: 15
# epoch=  328
# mov: 51
# epoch=  329
# mov: 51
# epoch=  330
# mov: 51
# epoch=  331
# mov: 2
# epoch=  332
# mov: 51
# epoch=  333
# mov: 9
# epoch=  334
# mov: 1
# epoch=  335
# mov: 7
# epoch=  336
# mov: 5
# epoch=  337
# mov: 21
# epoch=  338
# mov: 51
# epoch=  339
# mov: 51
# epoch=  340
# mov: 19
# epoch=  341
# mov: 1
# epoch=  342
# mov: 1
# epoch=  343
# mov: 1
# epoch=  344
# mov: 26
# epoch=  345
# mov: 41
# epoch=  346
# mov: 3
# epoch=  347
# mov: 23
# epoch=  348
# mov: 4
# epoch=  349
# mov: 3
# epoch=  350
# mov: 41
# epoch=  351
# mov: 3
# epoch=  352
# mov: 23
# epoch=  353
# mov: 38
# epoch=  354
# mov: 2
# epoch=  355
# mov: 5
# epoch=  356
# mov: 2
# epoch=  357
# mov: 49
# epoch=  358
# mov: 3
# epoch=  359
# mov: 51
# epoch=  360
# mov: 1
# epoch=  361
# mov: 51
# epoch=  362
# mov: 28
# epoch=  363
# mov: 51
# epoch=  364
# mov: 16
# epoch=  365
# mov: 51
# epoch=  366
# mov: 13
# epoch=  367
# mov: 10
# epoch=  368
# mov: 5
# epoch=  369
# mov: 10
# epoch=  370
# mov: 5
# epoch=  371
# mov: 9
# epoch=  372
# mov: 51
# epoch=  373
# mov: 51
# epoch=  374
# mov: 10
# epoch=  375
# mov: 27
# epoch=  376
# mov: 5
# epoch=  377
# mov: 1
# epoch=  378
# mov: 51
# epoch=  379
# mov: 7
# epoch=  380
# mov: 8
# epoch=  381
# mov: 1
# epoch=  382
# mov: 12
# epoch=  383
# mov: 7
# epoch=  384
# mov: 1
# epoch=  385
# mov: 27
# epoch=  386
# mov: 14
# epoch=  387
# mov: 2
# epoch=  388
# mov: 24
# epoch=  389
# mov: 8
# epoch=  390
# mov: 51
# epoch=  391
# mov: 47
# epoch=  392
# mov: 1
# epoch=  393
# mov: 36
# epoch=  394
# mov: 5
# epoch=  395
# mov: 2
# epoch=  396
# mov: 6
# epoch=  397
# mov: 10
# epoch=  398
# mov: 11
# epoch=  399
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 131
#     128 loss_tmp = loss_tmp + loss.numpy()
#     130 # Compute gradients of the loss with respect to the agent's trainable weights
# --> 131 grads = tape.gradient(loss, agent.trainable_weights)
#     132 # Apply the computed gradients to update the agent's weights (currently commented out)
#     133 optimizer.apply_gradients(zip(grads, agent.trainable_weights))
#
# File ~/repo_ai/Reinforcement_Learning/Einstieg_ReinforcementLearning/.venv/lib/python3.10/site-packages/tensorflow/python/eager/backprop.py:1113, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1107   output_gradients = (
#    1108       composite_tensor_gradient.get_flat_tensors_for_gradients(
#    1109           output_gradients))
#    1110   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1111                       for x in output_gradients]
# -> 1113 flat_grad = imperative_grad.imperative_grad(
#    1114     self._tape,
#    1115     flat_targets,
#    1116     flat_sources,
#    1117     output_gradients=output_gradients,
#    1118     sources_raw=flat_sources_raw,
#    1119     unconnected_gradients=unconnected_gradients)
#    1121 if not self._persistent:
#    1122   # Keep track of watched variables before setting tape to None
#    1123   self._watched_variables = self._tape.watched_variables()
#
# File ~/repo_ai/Reinforcement_Learning/Einstieg_ReinforcementLearning/.venv/lib/python3.10/site-packages/tensorflow/python/eager/imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File ~/repo_ai/Reinforcement_Learning/Einstieg_ReinforcementLearning/.venv/lib/python3.10/site-packages/tensorflow/python/eager/backprop.py:160, in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     158     gradient_name_scope += forward_pass_name_scope + "/"
#     159   with ops.name_scope(gradient_name_scope):
# --> 160     return grad_fn(mock_op, *out_grads)
#     161 else:
#     162   return grad_fn(mock_op, *out_grads)
#
# File ~/repo_ai/Reinforcement_Learning/Einstieg_ReinforcementLearning/.venv/lib/python3.10/site-packages/tensorflow/python/ops/array_grad.py:291, in _StridedSliceGrad(op, grad)
#     281 strides_static = tensor_util.constant_value(strides)
#     282 strides = strides_static if strides_static is not None else strides
#     284 return array_ops.strided_slice_grad(
#     285     x,
#     286     begin,
#     287     end,
#     288     strides,
#     289     grad,
#     290     begin_mask=op.get_attr("begin_mask"),
# --> 291     end_mask=op.get_attr("end_mask"),
#     292     ellipsis_mask=op.get_attr("ellipsis_mask"),
#     293     new_axis_mask=op.get_attr("new_axis_mask"),
#     294     shrink_axis_mask=op.get_attr("shrink_axis_mask")), None, None, None
#
# File ~/repo_ai/Reinforcement_Learning/Einstieg_ReinforcementLearning/.venv/lib/python3.10/site-packages/tensorflow/python/eager/backprop.py:118, in _MockOp.get_attr(self, attr)
#     116 for i in range(0, len(self.attrs), 2):
#     117   if self.attrs[i] == attr:
# --> 118     return make_attr(typ, self.attrs[i + 1])
#     119 raise KeyError(attr)
#
# File ~/repo_ai/Reinforcement_Learning/Einstieg_ReinforcementLearning/.venv/lib/python3.10/site-packages/tensorflow/python/eager/backprop.py:99, in make_attr(attr_type, value)
#      97 if attr_type == [int(pywrap_tfe.TF_ATTR_SHAPE)]:
#      98   return [tensor_shape.as_shape(v).as_proto() for v in value]
# ---> 99 return nest.map_structure(
#     100     lambda v: v.encode() if isinstance(v, str) else v,
#     101     value)
#
# File ~/repo_ai/Reinforcement_Learning/Einstieg_ReinforcementLearning/.venv/lib/python3.10/site-packages/tensorflow/python/util/nest.py:898, in map_structure(func, *structure, **kwargs)
#     895 if not callable(func):
#     896   raise TypeError("func must be callable, got: %s" % func)
# --> 898 if not structure:
#     899   raise ValueError("Must provide at least one structure")
#     901 check_types = kwargs.pop("check_types", True)
#
# KeyboardInterrupt:

# %%
#store weights:
agent.save_weights("agent_weights_ExperienceBasedRepeating.weights.h5")  # Saves weights in HDF5 format

# %%
#saving the list
import json
loss_ExperienceNetwork = loss_list.stack().numpy().tolist()
with open("loss_ExperienceNetwork.json","w") as f:
    json.dump(loss_ExperienceNetwork,f)

move_ExperienceNetwork = move_list.stack().numpy().tolist()
with open("move_ExperienceNetwork.json","w") as f:
    json.dump(move_ExperienceNetwork,f)

win_ExperienceNetwork = win_list.stack().numpy().tolist()
with open("win_ExperienceNetwork.json","w") as f:
    json.dump(win_ExperienceNetwork,f)

# %%
with open("loss_ExperienceNetwork.json","r") as f:
    loss2 = json.load(f)
with open("move_ExperienceNetwork.json","r") as f:
    moves = json.load(f)
with open("win_ExperienceNetwork.json","r") as f:
    win = json.load(f)

# ✅ Ensure moves is a NumPy array
moves = np.array(moves)

# ✅ Define epochs dynamically based on length of moves
epochs = np.arange(len(moves))  # Creates an array [0, 1, 2, ..., len(moves)-1]
# ✅ Compute Moving Average (SMA with window size = 3)
window_size = 20  # Adjust to control smoothness
moving_avg = np.convolve(moves, np.ones(window_size) / window_size, mode='valid')
moving_avg_win = np.convolve(win, np.ones(window_size) / window_size, mode='valid')

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 10))  # Two rows, one column

# ✅ First subplot: Loss over epochs
axes[0].plot(loss2, color='b', label="Loss")
axes[0].set_xlabel("Epochs", fontsize=16)
axes[0].set_ylabel("Loss", fontsize=16)
axes[0].set_title("Loss vs Epochs", fontsize=18)
axes[0].legend()
axes[0].grid(True)

# ✅ Second subplot: Moves over epochs
axes[1].plot(moves, color='r', label="Moves")
axes[1].plot(epochs[:len(moving_avg)], moving_avg, color='g', linestyle='dashed', linewidth=2, label="Moving Average")  # Moving average curve
axes[1].set_xlabel("Epochs", fontsize=16)
axes[1].set_ylabel("Moves", fontsize=16)
axes[1].set_title("Moves vs Epochs", fontsize=18)
axes[1].legend()
axes[1].grid(True)


# ✅ Third subplot: Moves over epochs
axes[2].plot(win, color='r', label="win")
axes[2].plot(epochs[:len(moving_avg_win)], moving_avg_win, color='g', linestyle='dashed', linewidth=2, label="Moving Average")  # Moving average curve
axes[2].set_xlabel("Epochs", fontsize=16)
axes[2].set_ylabel("win", fontsize=16)
axes[2].set_title("win vs Epochs", fontsize=18)
axes[2].legend()
axes[2].grid(True)


# Adjust layout for better spacing
plt.tight_layout()
plt.show()
